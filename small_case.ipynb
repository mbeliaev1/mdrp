# %%
import os
import sys
root = '/home/mark/Documents/code/mdrp'
sys.path.append(root)

import numpy as np
from utils.nlp_mdrp_elastic import mdrp_prob_elastic
import cyipopt

from utils.convert import convert_instance
# from utils.nlp_mdrp import mdrp_prob
from utils.helpers import *

rng = np.random.default_rng(seed=0)

# %%
# HELPER FUNCTIONS FOR NOTEBOOK #
def get_mu(s_time,t_time,beta,N,k):
    '''
    computers average service rate as the expected value for the given
    problem isntance
    '''
    expected_lat = (s_time+t_time+(k/(1+beta*N*(0.1)))).mean(axis=0)
    print(expected_lat)
    return 1/expected_lat

# max_dph = 100
# min_dph = 5
# alpha = lambda x : (1/max_dph) + ((1/min_dph)-(1/max_dph))*x 
# alpha_inv = lambda x: (x-(1/max_dph))/((1/min_dph)-(1/max_dph))

# %%
# Parameters for toy problem (INELASTIC)
# Units and rates are in hours
n_orders = 20
n_modes = 3
speeds = [1,2,0.3]
max_dph = 100
min_dph = 10
gamma = 2

prob_setup = {}

# same service time
prob_setup['s_time'] = np.ones((n_orders,n_modes))*(5/60) 
# travel time scaled by speeds
base_t_time = rng.random(n_orders)*30
# base_t_time = 15*np.ones()
prob_setup['t_time'] = np.array([base_t_time/speeds[0],
                                 base_t_time/speeds[1],
                                 base_t_time/speeds[2]]).T/60
# will be changed manually after
prob_setup['cost'] = np.ones((n_orders,n_modes))*(1) 
# same distribution for now
prob_setup['beta'] = np.ones((n_orders,n_modes))
# prob_setup['beta'] = rng.random((n_orders,n_modes))
# Set N so that setting makes sense
prob_setup['N'] = np.array([2,10,20])
# time radius considered for beta
prob_setup['k'] = np.ones(n_modes)*10/60
# compute mu which depends on N as well
prob_setup['mu'] = get_mu(prob_setup['s_time'],
                          prob_setup['t_time'],
                          prob_setup['beta'],
                          prob_setup['N'],
                          prob_setup['k'])

#ELASTIC DEMAND 
# properties of linear alpha function
# this controls the intrinsic value of ordering, higher means more demand
# NOTE: should be tuned to somewhere around latency we expect to wait (do later)
prob_setup['gamma'] = gamma
prob_setup['min_tau'] = 1e-9
# min_dph = prob_setup['min_tau']/prob_setup['gamma']

#  delta needs demand as well when defined this way
prob_setup['delta'] = (1/min_dph)-(1/max_dph)
prob_setup['alpha_0'] = (1/max_dph)

# constraints
prob_setup['max_rho'] = 0.9
prob_setup['max_cost'] = 10000 # irrelevant 
prob_setup['demand'] = 0.99
prob_setup['scale'] = True
# differents setups tested
# N_values = ([100,10,20],[80,10,35])
# # costs are set arbitrarily large to not allow for cars
# costs = ([10,200000,200000],[1,1,1])
# Out:
# [0.47839816 0.29475463 0.99280867]

# %%
# prob_setup['N'] = N_values[1]
# prob_setup['cost'][:,0] = costs[1][0]
# prob_setup['cost'][:,1] = costs[1][1]
# prob_setup['cost'][:,2] = costs[1][2]

mdrp = mdrp_prob_elastic(prob_setup)
lb, ub, cl, cu = mdrp.get_bounds()
x0 = mdrp.guess_init()

nlp = cyipopt.Problem(
    n=len(x0),
    m=len(cl),
    problem_obj=mdrp,
    lb=lb,
    ub=ub,
    cl=cl,
    cu=cu
    )

# nlp.addOption('derivative_test', 'second-order')
nlp.add_option('mu_strategy', 'adaptive')
nlp.add_option('tol', 1e-4)

nlp.set_problem_scaling(
    obj_scaling = -1
)

nlp.add_option('nlp_scaling_method', 'user-scaling')
# we are maximizing
x, info = nlp.solve(x0)
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.2.1.
#
# Number of nonzeros in equality constraint Jacobian...:     1600
# Number of nonzeros in inequality constraint Jacobian.:      240
# Number of nonzeros in Lagrangian Hessian.............:     3240
#
# Total number of variables............................:       80
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       80
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       20
# Total number of inequality constraints...............:        3
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        3
#         inequality constraints with only upper bounds:        0
#
# Objective value at iteration #0 is - 815.827
# (60, 60) (60, 60)
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.1582705e+02 4.44e-16 2.28e+02   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Objective value at iteration #1 is - 816.341
# (60, 60) (60, 60)
#    1  8.1634104e+02 5.03e-04 1.79e+02   1.0 1.82e-02   4.0 9.91e-01 1.00e+00f  1
# Objective value at iteration #2 is - 816.965
# (60, 60) (60, 60)
#    2  8.1696466e+02 1.09e-04 1.05e+02   1.0 3.27e-02   3.5 9.94e-01 1.00e+00h  1
# Objective value at iteration #3 is - 817.633
# (60, 60) (60, 60)
#    3  8.1763273e+02 9.96e-05 7.91e+01  -0.2 7.91e-02   3.0 9.97e-01 9.45e-01H  1
# Objective value at iteration #4 is - 817.756
# (60, 60) (60, 60)
#    4  8.1775565e+02 2.14e-04 7.97e+01  -1.0 2.79e-02   3.5 1.00e+00 1.00e+00f  1
# Objective value at iteration #5 is - 817.936
# (60, 60) (60, 60)
#    5  8.1793609e+02 2.12e-03 7.58e+01  -2.0 9.70e-02   3.0 1.00e+00 1.00e+00f  1
# Objective value at iteration #6 is - 817.947
# (60, 60) (60, 60)
#    6  8.1794685e+02 2.12e-04 7.41e+01  -3.1 2.93e-02   3.4 1.00e+00 1.00e+00f  1
# Objective value at iteration #7 is - 817.771
# (60, 60) (60, 60)
#    7  8.1777104e+02 2.60e-05 6.92e+01  -4.1 1.05e-01   2.9 1.00e+00 1.00e+00H  1
# Objective value at iteration #8 is - 817.771
# (60, 60) (60, 60)
#    8  8.1777104e+02 2.60e-05 3.01e+02  -5.3 2.91e-02   3.4 1.00e+00 7.28e-12h 38
# Objective value at iteration #9 is - 817.771
# (60, 60) (60, 60)
#    9  8.1777104e+02 2.60e-05 1.32e+02  -5.2 1.17e-01   2.9 1.00e+00 2.78e-12h 39
# Objective value at iteration #10 is - 817.629
# (60, 60) (60, 60)
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  8.1762900e+02 2.39e-04 6.53e+01  -5.2 3.29e-02   3.3 1.00e+00 1.00e+00s 51
# Objective value at iteration #11 is - 817.629
#   11r 8.1762900e+02 2.39e-04 1.00e+03  -3.6 0.00e+00   2.8 0.00e+00 0.00e+00R  1
# Objective value at iteration #12 is - 817.64
# (60, 60) (60, 60)
#   12r 8.1764035e+02 6.11e-05 9.99e+00  -2.2 3.63e+00    -  9.90e-01 1.01e-03f  1
# Objective value at iteration #13 is - 816.753
# (60, 60) (60, 60)
#   13r 8.1675347e+02 1.13e-02 9.38e-02  -1.9 1.11e+00    -  9.91e-01 1.00e+00f  1
# Objective value at iteration #14 is - 824.287
# (60, 60) (60, 60)
#   14r 8.2428674e+02 9.09e-02 7.25e-03  -2.0 4.26e-01  -2.0 1.00e+00 1.00e+00f  1
# Objective value at iteration #15 is - 818.216
# (60, 60) (60, 60)
#   15r 8.1821597e+02 1.02e-02 7.82e-03  -3.0 5.70e-01  -2.5 9.97e-01 1.00e+00h  1
# Objective value at iteration #16 is - 818.601
# (60, 60) (60, 60)
#   16r 8.1860072e+02 9.75e-04 4.75e-03  -3.9 5.19e-02  -2.1 9.66e-01 1.00e+00h  1
# Objective value at iteration #17 is - 816.743
# (60, 60) (60, 60)
#   17r 8.1674260e+02 1.92e-02 5.04e-04  -4.9 1.49e+00    -  9.99e-01 1.00e+00h  1
# Objective value at iteration #18 is - 817.394
# (60, 60) (60, 60)
#   18r 8.1739382e+02 3.03e-04 1.33e-04  -6.0 2.73e-02  -2.5 1.00e+00 1.00e+00h  1
# Objective value at iteration #19 is - 817.484
# (60, 60) (60, 60)
#   19r 8.1748364e+02 2.71e-04 4.39e-05  -7.7 2.44e-02  -3.0 1.00e+00 1.00e+00h  1
# Objective value at iteration #20 is - 817.506
# (60, 60) (60, 60)
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 8.1750584e+02 4.91e-05 4.93e-06  -9.0 9.86e-03  -3.5 1.00e+00 1.00e+00h  1
# Objective value at iteration #21 is - 817.525
# (60, 60) (60, 60)
#   21r 8.1752540e+02 3.10e-05 7.36e-07  -9.0 6.83e-03  -4.0 1.00e+00 1.00e+00h  1
# Objective value at iteration #22 is - 817.064
# (60, 60) (60, 60)
#   22r 8.1706431e+02 8.05e-03 1.59e-05  -6.9 1.39e+00    -  1.00e+00 8.48e-01h  1
# Objective value at iteration #23 is - 817.996
# (60, 60) (60, 60)
#   23r 8.1799571e+02 4.75e-03 9.01e-07  -7.0 8.61e-01    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #24 is - 817.672
# (60, 60) (60, 60)
#   24r 8.1767172e+02 4.98e-04 2.65e-07  -7.0 1.09e-01    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #25 is - 817.661
# (60, 60) (60, 60)
#   25r 8.1766133e+02 9.12e-05 4.69e-08  -7.0 6.96e-02    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #26 is - 817.628
# (60, 60) (60, 60)
#   26r 8.1762796e+02 1.70e-05 2.38e-08  -7.0 2.69e-02    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #27 is - 817.622
# (60, 60) (60, 60)
#   27r 8.1762216e+02 3.90e-05 4.89e-07  -9.0 2.56e-02    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #28 is - 817.647
# Objective value at iteration #28 is - 817.647
#   28r 8.1764710e+02 1.36e-05 1.23e-08  -9.0 3.85e-02    -  1.00e+00 1.00e+00h  1
# (60, 60) (60, 60)
# Objective value at iteration #29 is - 817.694
# (60, 60) (60, 60)
#   29  8.1769408e+02 3.02e-05 1.52e+03  -4.5 1.06e+00   2.4 1.00e+00 6.61e-03f  1
# Objective value at iteration #30 is - 817.693
# (60, 60) (60, 60)
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  8.1769278e+02 3.02e-05 4.21e+03  -2.0 1.13e+00   1.9 1.00e+00 2.82e-04h  3
# Objective value at iteration #31 is - 817.69
# (60, 60) (60, 60)
#   31  8.1768968e+02 3.02e-05 4.06e+03  -2.0 2.84e-01   2.3 1.00e+00 1.95e-03h  8
# Objective value at iteration #32 is - 817.69
# (60, 60) (60, 60)
#   32  8.1768968e+02 3.02e-05 4.12e+03  -2.0 3.80e+00   1.8 1.40e-01 9.24e-14h 40
# Objective value at iteration #33 is - 817.688
# (60, 60) (60, 60)
#   33  8.1768758e+02 3.01e-05 4.06e+03  -2.0 3.20e-01   2.3 1.00e+00 1.16e-03h  9
# Objective value at iteration #34 is - 817.683
# (60, 60) (60, 60)
#   34  8.1768255e+02 2.99e-05 3.96e+03  -2.0 1.23e-01   2.7 1.00e+00 7.45e-03h  8
# Objective value at iteration #35 is - 817.681
# (60, 60) (60, 60)
#   35  8.1768053e+02 2.99e-05 4.04e+03  -2.0 3.63e-01   2.2 1.00e+00 9.67e-04h 10
# Objective value at iteration #36 is - 816.588
# (60, 60) (60, 60)
#   36  8.1658802e+02 1.15e-06 6.07e+01  -2.0 1.38e-01   2.6 1.00e+00 1.00e+00H  1
# Objective value at iteration #37 is - 816.588
# (60, 60) (60, 60)
#   37  8.1658802e+02 1.15e-06 6.07e+01  -3.0 5.42e-02   3.1 1.00e+00 2.48e-12h 39
# Objective value at iteration #38 is - 816.588
# (60, 60) (60, 60)
#   38  8.1658809e+02 6.39e-06 1.06e+02  -2.7 1.46e+00   2.6 1.94e-01 7.25e-03f  5
# Objective value at iteration #39 is - 816.588
# (60, 60) (60, 60)
#   39  8.1658809e+02 6.39e-06 6.06e+01  -4.2 6.38e-02   3.0 1.00e+00 2.15e-12h 38
# Objective value at iteration #40 is - 816.588
# (60, 60) (60, 60)
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  8.1658809e+02 6.39e-06 1.02e+02  -3.0 2.10e-02   3.4 1.00e+00 7.28e-12h 38
# Objective value at iteration #41 is - 816.279
# (60, 60) (60, 60)
#   41  8.1627919e+02 1.92e-04 5.78e+01  -3.0 7.56e-02   3.0 4.66e-01 4.66e-01s 53
# Objective value at iteration #42 is - 816.039
# (60, 60) (60, 60)
#   42  8.1603941e+02 9.80e-05 5.45e+01  -3.0 2.31e-02   3.4 1.00e+00 1.00e+00s 53
# Objective value at iteration #43 is - 816.039
#   43r 8.1603941e+02 9.80e-05 1.00e+03  -3.0 0.00e+00   2.9 0.00e+00 0.00e+00R  1
# Objective value at iteration #44 is - 797.611
# (60, 60) (60, 60)
#   44r 7.9761059e+02 1.90e-01 9.90e+00  -1.0 4.80e+01    -  9.90e-01 1.10e-01f  1
# Objective value at iteration #45 is - 813.78
# (60, 60) (60, 60)
#   45r 8.1378044e+02 7.54e-03 5.86e-01  -1.1 5.03e-01  -2.0 9.44e-01 1.00e+00f  1
# Objective value at iteration #46 is - 818.48
# (60, 60) (60, 60)
#   46r 8.1847964e+02 2.62e-02 3.09e-02  -1.8 1.19e-01  -0.7 1.00e+00 1.00e+00f  1
# Objective value at iteration #47 is - 816.805
# (60, 60) (60, 60)
#   47r 8.1680476e+02 2.63e-04 3.50e-02  -2.8 6.63e-02  -1.1 9.75e-01 1.00e+00f  1
# Objective value at iteration #48 is - 816.791
# (60, 60) (60, 60)
#   48r 8.1679122e+02 1.43e-04 3.81e-03  -3.6 5.47e-02  -1.6 1.00e+00 1.00e+00f  1
# Objective value at iteration #49 is - 816.676
# (60, 60) (60, 60)
#   49r 8.1667631e+02 1.14e-03 1.68e-03  -4.9 5.32e-02  -2.1 1.00e+00 1.00e+00h  1
# Objective value at iteration #50 is - 816.508
# (60, 60) (60, 60)
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50r 8.1650781e+02 2.37e-04 3.77e-04  -6.2 3.01e-02  -2.6 1.00e+00 1.00e+00h  1
# Objective value at iteration #51 is - 816.454
# (60, 60) (60, 60)
#   51r 8.1645363e+02 6.50e-05 8.46e-05  -8.0 2.00e-02  -3.1 1.00e+00 1.00e+00h  1
# Objective value at iteration #52 is - 816.44
# (60, 60) (60, 60)
#   52r 8.1644003e+02 9.55e-06 8.63e-06  -9.0 8.28e-03  -3.5 1.00e+00 1.00e+00h  1
# Objective value at iteration #53 is - 816.436
# (60, 60) (60, 60)
#   53r 8.1643633e+02 1.10e-05 9.39e-07  -9.0 9.63e-03  -4.0 1.00e+00 1.00e+00h  1
# Objective value at iteration #54 is - 816.419
# (60, 60) (60, 60)
#   54r 8.1641852e+02 6.05e-05 7.79e-07  -9.0 2.35e-02  -4.5 1.00e+00 1.00e+00h  1
# Objective value at iteration #55 is - 816.4
# (60, 60) (60, 60)
#   55r 8.1640023e+02 8.45e-05 5.64e-06  -8.2 7.15e-02  -5.0 1.00e+00 1.00e+00h  1
# Objective value at iteration #56 is - 813.849
# (60, 60) (60, 60)
#   56r 8.1384921e+02 9.20e-02 1.29e-06  -8.3 4.27e+00    -  3.41e-01 1.00e+00h  1
# Objective value at iteration #57 is - 816.215
# (60, 60) (60, 60)
#   57r 8.1621493e+02 6.62e-04 1.32e-06  -9.0 1.50e-01  -5.4 1.00e+00 1.00e+00h  1
# Objective value at iteration #58 is - 815.508
# (60, 60) (60, 60)
#   58r 8.1550815e+02 2.82e-02 2.48e-06  -7.9 1.88e+00    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #59 is - 815.932
# (60, 60) (60, 60)
#   59r 8.1593220e+02 6.28e-03 1.02e-06  -8.0 9.42e-01    -  1.00e+00 9.15e-01h  1
# Objective value at iteration #60 is - 816.04
# (60, 60) (60, 60)
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60r 8.1603991e+02 1.02e-04 8.12e-09  -8.0 1.93e-02    -  1.00e+00 1.00e+00f  1
# Objective value at iteration #61 is - 816.036
# (60, 60) (60, 60)
#   61r 8.1603624e+02 1.96e-05 2.81e-07  -9.0 2.30e-02    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #62 is - 816.038
#   62r 8.1603765e+02 7.58e-07 3.01e-10  -9.0 4.34e-03    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #62 is - 816.038
# (60, 60) (60, 60)
# Objective value at iteration #63 is - 816.038
# (60, 60) (60, 60)
#   63  8.1603765e+02 7.58e-07 1.19e+02  -3.0 5.11e-01   2.4 3.54e-01 3.34e-13f 36
# Objective value at iteration #64 is - 816.038
# (60, 60) (60, 60)
#   64  8.1603765e+02 7.58e-07 1.33e+03  -3.0 1.04e+00   2.0 3.93e-01 1.36e-13h 37
# Objective value at iteration #65 is - 815.043
# (60, 60) (60, 60)
#   65  8.1504275e+02 9.00e-04 8.50e+02  -3.0 2.00e-01   2.4 3.59e-01 3.59e-01s 56
# Objective value at iteration #66 is - 814.646
# (60, 60) (60, 60)
#   66  8.1464575e+02 7.09e-04 5.32e+02  -3.0 8.05e-02   2.8 3.75e-01 3.75e-01s 56
# Objective value at iteration #67 is - 814.611
# (60, 60) (60, 60)
#   67  8.1461069e+02 7.43e-04 5.27e+02  -3.0 3.12e+00   2.3 8.48e-03 8.48e-03s 56
# Objective value at iteration #68 is - 813.802
# (60, 60) (60, 60)
#   68  8.1380226e+02 7.65e-04 2.16e+02  -3.0 1.02e-01   2.8 5.90e-01 5.90e-01s 56
# Objective value at iteration #69 is - 813.382
# (60, 60) (60, 60)
#   69  8.1338175e+02 2.09e-04 4.55e+01  -3.0 3.22e-02   3.2 8.83e-01 8.83e-01s 56
# Objective value at iteration #70 is - 813.205
# (60, 60) (60, 60)
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  8.1320497e+02 2.08e-04 4.53e+01  -3.0 1.56e-01   2.7 9.78e-02 9.78e-02s 56
# Objective value at iteration #71 is - 812.62
# (60, 60) (60, 60)
#   71  8.1262005e+02 1.81e-04 4.44e+01  -3.0 3.59e-02   3.1 9.99e-01 9.99e-01s 56
# Objective value at iteration #72 is - 812.62
#   72r 8.1262005e+02 1.81e-04 1.00e+03  -3.0 0.00e+00   2.7 0.00e+00 0.00e+00R  1
# Objective value at iteration #73 is - 812.623
# (60, 60) (60, 60)
#   73r 8.1262263e+02 4.50e-05 1.00e+01  -4.0 5.44e-02    -  9.90e-01 5.48e-03f  1
# Objective value at iteration #74 is - 795.92
# (60, 60) (60, 60)
#   74r 7.9592041e+02 1.62e-01 1.46e-01  -2.2 1.39e+01    -  9.91e-01 3.48e-01f  1
# Objective value at iteration #75 is - 815.133
# (60, 60) (60, 60)
#   75r 8.1513256e+02 3.51e-02 9.93e-03  -2.3 1.09e+00  -2.0 1.00e+00 1.00e+00f  1
# Objective value at iteration #76 is - 803.127
# (60, 60) (60, 60)
#   76r 8.0312713e+02 4.35e-01 6.03e-02  -2.3 2.86e+01    -  5.46e-01 2.79e-01h  2
# Objective value at iteration #77 is - 805.056
# (60, 60) (60, 60)
#   77r 8.0505594e+02 8.41e-02 2.44e-02  -2.7 2.33e+00  -2.5 9.02e-01 1.00e+00h  1
# Objective value at iteration #78 is - 810.831
# (60, 60) (60, 60)
#   78r 8.1083112e+02 3.97e-02 3.23e-03  -3.2 1.13e+00  -3.0 9.61e-01 1.00e+00h  1
# Objective value at iteration #79 is - 811.031
# (60, 60) (60, 60)
#   79r 8.1103072e+02 5.47e-02 1.83e-03  -3.9 2.05e+00    -  9.02e-01 1.00e+00h  1
# Objective value at iteration #80 is - 812.651
# (60, 60) (60, 60)
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80r 8.1265098e+02 1.83e-04 4.34e-04  -4.8 7.62e-02  -3.4 9.94e-01 1.00e+00h  1
# Objective value at iteration #81 is - 812.618
# (60, 60) (60, 60)
#   81r 8.1261806e+02 1.65e-04 1.57e-04  -6.3 5.91e-02  -3.9 9.99e-01 1.00e+00h  1
# Objective value at iteration #82 is - 812.61
# (60, 60) (60, 60)
#   82r 8.1260978e+02 3.23e-05 2.50e-05  -7.9 2.66e-02  -4.4 1.00e+00 1.00e+00h  1
# Objective value at iteration #83 is - 812.601
# (60, 60) (60, 60)
#   83r 8.1260089e+02 1.47e-05 2.75e-06  -9.0 1.51e-02  -4.9 1.00e+00 1.00e+00h  1
# Objective value at iteration #84 is - 812.632
# (60, 60) (60, 60)
#   84r 8.1263229e+02 1.83e-03 7.19e-08  -9.0 4.47e-01    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #85 is - 812.588
# (60, 60) (60, 60)
#   85r 8.1258795e+02 8.76e-04 3.19e-08  -9.0 3.32e-01    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #86 is - 812.625
# (60, 60) (60, 60)
#   86r 8.1262496e+02 2.26e-04 8.83e-09  -9.0 1.58e-01    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #87 is - 812.623
# (60, 60) (60, 60)
#   87r 8.1262278e+02 5.17e-06 9.85e-10  -9.0 2.59e-02    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #88 is - 812.624
#   88r 8.1262362e+02 2.92e-07 9.21e-11  -9.0 5.81e-03    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #88 is - 812.624
# (60, 60) (60, 60)
# Objective value at iteration #89 is - 812.624
# (60, 60) (60, 60)
#   89  8.1262362e+02 2.92e-07 4.69e+02  -3.0 9.02e-01   2.2 4.60e-01 5.21e-14f 37
# Objective value at iteration #90 is - 812.624
# (60, 60) (60, 60)
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  8.1262362e+02 2.92e-07 3.22e+03  -3.0 9.91e-02   2.6 1.00e+00 5.30e-13h 39
# Objective value at iteration #91 is - 808.952
# (60, 60) (60, 60)
#   91  8.0895223e+02 4.10e-03 1.59e+03  -3.0 3.56e-01   2.1 5.05e-01 5.05e-01s 60
# Objective value at iteration #92 is - 806.753
# (60, 60) (60, 60)
#   92  8.0675265e+02 2.14e-03 3.02e+02  -3.0 1.47e-01   2.6 8.10e-01 8.10e-01s 60
# Objective value at iteration #93 is - 805.919
# (60, 60) (60, 60)
#   93  8.0591884e+02 1.95e-04 3.65e+01  -3.0 4.29e-02   3.0 1.00e+00 1.00e+00s 60
# Objective value at iteration #94 is - 805.919
#   94r 8.0591884e+02 1.95e-04 1.00e+03  -3.0 0.00e+00   2.5 0.00e+00 0.00e+00R  1
# Objective value at iteration #95 is - 805.922
# (60, 60) (60, 60)
#   95r 8.0592209e+02 4.80e-05 1.00e+01  -4.1 5.56e-02    -  9.90e-01 5.10e-03f  1
# Objective value at iteration #96 is - 806.006
# (60, 60) (60, 60)
#   96r 8.0600624e+02 4.50e-05 1.00e-01  -4.8 6.42e-02    -  9.90e-01 9.81e-01f  1
# Objective value at iteration #97 is - 805.878
# (60, 60) (60, 60)
#   97r 8.0587818e+02 1.52e-02 2.47e-03  -3.8 9.80e-01    -  9.99e-01 1.00e+00f  1
# Objective value at iteration #98 is - 811.651
# (60, 60) (60, 60)
#   98r 8.1165120e+02 5.11e-02 3.38e-04  -3.9 7.19e-01    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #99 is - 807.515
# (60, 60) (60, 60)
#   99r 8.0751536e+02 5.33e-03 1.88e-04  -3.9 8.13e-01  -4.0 1.00e+00 1.00e+00h  1
# Objective value at iteration #100 is - 806.187
# (60, 60) (60, 60)
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100r 8.0618706e+02 5.22e-03 1.95e-04  -3.9 5.39e-01  -3.6 1.00e+00 1.00e+00h  1
# Objective value at iteration #101 is - 806.461
# (60, 60) (60, 60)
#  101r 8.0646067e+02 1.22e-03 8.78e-06  -3.9 2.38e-01    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #102 is - 806.025
# (60, 60) (60, 60)
#  102r 8.0602477e+02 2.65e-03 4.41e-04  -5.0 5.63e-01    -  9.79e-01 1.00e+00h  1
# Objective value at iteration #103 is - 805.902
# (60, 60) (60, 60)
#  103r 8.0590203e+02 1.31e-05 8.98e-05  -6.6 1.57e-02  -3.1 1.00e+00 1.00e+00h  1
# Objective value at iteration #104 is - 805.835
# (60, 60) (60, 60)
#  104r 8.0583481e+02 6.39e-06 1.33e-05  -8.4 6.39e-03  -3.6 1.00e+00 1.00e+00h  1
# Objective value at iteration #105 is - 805.798
# (60, 60) (60, 60)
#  105r 8.0579760e+02 2.21e-06 7.81e-07  -9.0 3.29e-03  -4.1 1.00e+00 1.00e+00h  1
# Objective value at iteration #106 is - 805.863
# (60, 60) (60, 60)
#  106r 8.0586325e+02 7.62e-04 2.82e-08  -9.0 2.87e-01    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #107 is - 805.897
# (60, 60) (60, 60)
#  107r 8.0589716e+02 1.84e-05 2.53e-09  -9.0 5.16e-02    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #108 is - 805.914
# (60, 60) (60, 60)
#  108r 8.0591449e+02 1.87e-06 4.34e-10  -9.0 1.10e-02    -  1.00e+00 1.00e+00h  1
# Objective value at iteration #109 is - 805.922
# Restoration phase converged to a feasible point that is
# unacceptable to the filter for the original problem.
# Restoration phase in the restoration phase failed.
#
# Number of Iterations....: 108
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -8.0592190340719333e+02    8.0592190340719333e+02
# Dual infeasibility......:   9.6826081262587692e+01    9.6826081262587692e+01
# Constraint violation....:   7.2661749506153228e-08    7.2661749506153228e-08
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.0600218357537371e-09    1.0600218357537371e-09
# Overall NLP error.......:   9.6826081262587692e+01    9.6826081262587692e+01
#
#
# Number of objective function evaluations             = 791
# Number of objective gradient evaluations             = 47
# Number of equality constraint evaluations            = 791
# Number of inequality constraint evaluations          = 791
# Number of equality constraint Jacobian evaluations   = 114
# Number of inequality constraint Jacobian evaluations = 114
# Number of Lagrangian Hessian evaluations             = 109
# Total seconds in IPOPT                               = 3.593
#
# EXIT: Restoration Failed!

# %%
# x  = mdrp.guess_init()

print(mdrp.objective(x).shape)
print(mdrp.constraints(x).shape)
# print(mdrp.gradient(x).shape)
# print(mdrp.jacobian(x).shape)
# print(mdrp.hessian(x, np.ones(mdrp.n+mdrp.n),1).shape)

print(mdrp.objective(x))
print(mdrp.constraints(x))
# print(mdrp.gradient(x))
# print(mdrp.jacobian(x))
# print(mdrp.hessian(x, np.ones(mdrp.n+mdrp.n),1))
# Out:
# ()
# (23,)
# 805.9219034071933
# [ 8.96891998e-01  7.13638599e-01  8.99143798e-01  3.15924531e-08
#   4.70543573e-08  2.31408595e-08  7.26617495e-08  4.67724708e-08
#   2.36812168e-08  3.08042347e-08  5.42692757e-08  4.45195845e-08
#   1.76034272e-08  4.08708796e-08  2.83012502e-08  2.55555708e-08
#  -1.97785877e-09  4.77331024e-08  1.48617185e-08  3.76846745e-08
#   2.21923746e-08  3.48106819e-08  1.43426098e-08]

# %%
flow, tau = mdrp.split_x(x)
print('util: ',mdrp.get_util(flow))
print('price:',tau)
print('obj: ',mdrp.objective(x))
print('Total Utilization: %.2f'%(100*flow.sum()/(mdrp.demand*mdrp.n)))
# print('Avg mode latency: ',mdrp.lat.mean(axis=0)*60)
# Out:
# util:  [0.896892  0.7136386 0.8991438]
# price: [ 8.80976827 14.58476118 18.01724664 18.02951163  5.98358795  4.57138925
#   9.24145209  7.40245484 10.17024252  4.19463071  5.86959608 18.16498418
#   5.49295018 17.90958382  7.19565326 16.25588328  5.24905322 10.38920894
#  14.05037275 12.33555886]
# obj:  805.9219034071933
# Total Utilization: 88.77

# %%
print(flow.sum(axis=1))
print(mdrp.demand)
# Out:
# [2.3295091  2.50281038 2.52516102 2.54279527 2.14993698 1.85730931
#  2.36492708 2.22645033 2.4203663  1.79434634 2.17613912 2.53262525
#  1.98159849 2.54802171 2.29766394 2.49415987 2.0342014  2.37328564
#  2.5066125  2.41605311]
# 2.595127046821611

# %% [markdown]
# Intermediate steps
#
# - objective (easy)
#
# - gradient
#     * get $\frac{d\tau_{i',j'}}{dx_{i,j}}$
#     * get $d_{i,j}$

# %%
# eval_setup = {}
# eval_setup['max_dph'] = 100
# eval_setup['min_dph'] = 5
# eval_setup['min_price'] = 10
# eval_setup['mode_names'] = ['cars','drones','droids']
# eval_setup['speeds'] = [1,2,0.3]

# print('Evaluation')
# print('Mean delivery rate mu: ',(1/mdrp.mu)*60)
# eval_sol(x,mdrp,eval_setup)

# %%
# prob_setup['N'] = N_values[1]
# prob_setup['cost'][:,0] = costs[1][0]
# prob_setup['cost'][:,1] = costs[1][1]
# prob_setup['cost'][:,2] = costs[1][2]
# mdrp = mdrp_prob(prob_setup)
# lb, ub, cl, cu = mdrp.get_bounds()
# x0 = mdrp.guess_init()

# nlp = cyipopt.Problem(
#     n=len(x0),
#     m=len(cl),
#     problem_obj=mdrp,
#     lb=lb,
#     ub=ub,
#     cl=cl,
#     cu=cu
#     )

# # nlp.addOption('derivative_test', 'second-order')
# nlp.add_option('mu_strategy', 'adaptive')
# nlp.add_option('tol', 1e-4)

# x, info = nlp.solve(x0)

# %%
# eval_setup = {}
# eval_setup['max_dph'] = 100
# eval_setup['min_dph'] = 5
# eval_setup['min_price'] = 10
# eval_setup['mode_names'] = ['cars','drones','droids']
# eval_setup['speeds'] = [1,2,0.3]

# print('Evaluation')
# print('Mean delivery rate mu: ',(1/mdrp.mu)*60)
# eval_sol(x,mdrp,eval_setup)
